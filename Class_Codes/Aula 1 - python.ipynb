# %%
def insert_sort(x):
    for i in range(len(x)):
        value = x[i]
        j = i - 1
        while j >= 0 and x[j] > value:
            x[j+1] = x[j]
            j = j - 1
        x[j+1] = value
    return x

# %%
import numpy as np

# %%
A = np.random.random(size = 1000)
A
# Out:
# array([4.50387543e-02, 6.62328492e-01, 2.67583481e-01, 3.16534256e-01,
#        6.43307875e-01, 9.27605330e-01, 7.83283096e-01, 9.44970860e-01,
#        9.06551383e-01, 6.68605253e-01, 2.67420090e-01, 6.45071280e-01,
#        6.83426819e-01, 7.29326474e-01, 1.04756730e-01, 4.67850644e-01,
#        6.37814705e-01, 6.81741074e-01, 2.24616515e-01, 2.61000868e-01,
#        8.57318785e-01, 6.27998617e-01, 9.89538275e-01, 3.21720832e-01,
#        3.83698761e-01, 8.37472505e-01, 6.33012254e-01, 6.08087570e-02,
#        4.71359086e-01, 6.41703925e-01, 3.37907926e-01, 2.57681901e-02,
#        2.45525647e-01, 5.37160389e-02, 3.76204349e-01, 2.33142325e-01,
#        7.10967034e-01, 5.12319335e-01, 9.67948611e-01, 4.24670098e-01,
#        5.95123686e-01, 1.14813663e-01, 2.76247369e-01, 8.74227299e-01,
#        3.57009061e-01, 4.56621273e-01, 8.32144477e-01, 5.28804268e-01,
#        4.89770348e-03, 1.53058087e-01, 4.47412964e-01, 4.27805134e-01,
# ...

# %%
A = [10,431,24,7,2,5,8,2,41,5]

# %%
insert_sort(A)
# Out:
# array([5.75199348e-04, 1.54105672e-03, 2.26904996e-03, 3.40129444e-03,
#        4.89770348e-03, 6.20368522e-03, 6.93455653e-03, 8.07360132e-03,
#        8.50196395e-03, 8.70831919e-03, 9.86215249e-03, 1.01359110e-02,
#        1.09928309e-02, 1.16429433e-02, 1.28471049e-02, 1.47633630e-02,
#        1.49405440e-02, 1.68159768e-02, 1.81002702e-02, 1.81734808e-02,
#        1.87441390e-02, 1.90926984e-02, 1.91964856e-02, 1.96432235e-02,
#        2.06099842e-02, 2.57681901e-02, 2.63098583e-02, 2.63604888e-02,
#        2.65192679e-02, 2.70653901e-02, 2.73521011e-02, 2.81014929e-02,
#        3.25821586e-02, 3.26622902e-02, 3.30758246e-02, 3.31537082e-02,
#        3.39115202e-02, 3.42701448e-02, 3.48509679e-02, 3.66927933e-02,
#        3.67037228e-02, 3.80772519e-02, 3.84569839e-02, 3.91082086e-02,
#        3.97347362e-02, 4.11370390e-02, 4.23671045e-02, 4.50387543e-02,
#        4.63940343e-02, 4.69630543e-02, 4.71874000e-02, 4.74888345e-02,
# ...
